# %%
import numpy as np
import pandas as pd
import csv

# Path to your CSV file
file_path = '/content/Transfer data project - Staging (22).csv'

# List to hold the rows
rows_list = []

try:
    with open(file_path, 'r', newline='', encoding='utf-8') as csvfile:
        csvreader = csv.reader(csvfile)

        # Skip the header row if there is one


        # Loop through the rows and add them to the list
        for row in csvreader:
            rows_list.extend(row)
except FileNotFoundError:
    print(f"Error: The file {file_path} was not found.")
except Exception as e:
    print(f"An error occurred: {e}")
print(rows_list)













def process_rows(rows_list):
    lll = []



    # Collect names until '#' is found
    names = []
    while rows_list and rows_list[0] in ["2020", "2021", "2022", "2023", "2019", "2018", "2017", "2016", "2015", "2014"]:
        names.append(rows_list.pop(0))  # Remove the first element

    # Reset index for new processing
    j = 0

    while names and rows_list and rows_list[0] not in ["2020", "2021", "2022", "2023", "2019", "2018", "2017", "2016", "2015", "2014"]:
        ll = [names[j]]
        j += 1
        while rows_list:
            item = rows_list.pop(0)  # Remove the first element
            ll.append(item)
            if '(' in item:
                break

        lll.append(ll)

    # Recursively call the function to process the remaining rows
    return lll





result = process_rows(rows_list)








while len(rows_list) > 0:
  result.extend(process_rows(rows_list))


print(result[-16])
print(len(result))

print(rows_list)
# print(len(lll))
for item in result:
  print(len(item))
  if len(item) < 39:
    result.remove(item)

for item in result:
  #print(len(item))
  if len(item) == 40:
    item.pop(-7)

for item in result:
  if len(item) != 39:
    result.remove(item)
# for item in lll:
#   if len(item) == 40:
#     print(item[-7])
#     item.insert(-6,0)
# for item in result:
#   print(len(item))


print(len(result))







csv_file = 'output.csv'

#column_titles = ['Name', 'Rating', 'Position', 'Height', 'Weight', 'Former School', 'Transfer School']
x=[]
x1 = []
x2 = []
x3 = []
x4 = []
x5 = []
x6 = []
x7 = []
x8 = []
x9 = []
x10 = []
x11 = []
x12 = []
x13 = []
x14 = []
x15 = []
x16 = []
x17 = []
x18 = []
x19 = []
x20 = []
x21 = []
x22 = []
x23 = []
x24 = []
x25 = []
x26 = []
x27 = []
x28 = []
x29 = []
x30 = []
x31 = []
x32 = []
x33 = []
x34 = []
x35 = []
x36 = []
x37 = []
x38 = []








for item in result:
    x.append(item[0])
    x1.append(item[1])
    x2.append(item[2])
    x3.append(item[3])
    x4.append(item[4])
    x5.append(item[5])
    x6.append(item[6])
    x7.append(item[7])
    x8.append(item[8])
    x9.append(item[9])
    x10.append(item[10])
    x11.append(item[11])
    x12.append(item[12])
    x13.append(item[13])
    x14.append(item[14])
    x15.append(item[15])
    x16.append(item[16])
    x17.append(item[17])
    x18.append(item[18])
    x19.append(item[19])
    x20.append(item[20])
    x21.append(item[21])
    x22.append(item[22])
    x23.append(item[23])
    x24.append(item[24])
    x25.append(item[25])
    x26.append(item[26])
    x27.append(item[27])
    x28.append(item[28])
    x29.append(item[29])
    x30.append(item[30])
    x31.append(item[31])
    x32.append(item[32])
    x33.append(item[33])
    x34.append(item[34])
    x35.append(item[35])
    x36.append(item[36])
    x37.append(item[37])
    x38.append(item[38])








with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)



    for data in zip(x, x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,x16,x17,x18,x19,x20,x21,x22,x23,x24,x25,x26,x27,x28,x29,x30,x31,x32,x33,x34,x35,x36,x37,x38):
        writer.writerow(data)
# Out:
# ['2023', '2022', 'E TENN ST', '56', '23', '41.1', '349', '15.2', '0', '60', '60.9', '57.5', '75.4', '-', '233', '226', '97', '0', '0', '86', '36.9', '144', '61.8', '0', '0', '144', '6.3', '1.54', '12.1', '37', '3', '11.5', '7', '2', '28.6', '5', '0', '3', '13', '25.1', '1 (0)', '2023', '2022', '2021', '2019', 'LA MONROE', '51', '24', '47.1', '400', '16.7', '2', '54.6', '54.9', '50', '28.1', '-', '327', '304', '93', '0', '0', '11', '3.4', '316', '96.6', '0', '0', '137', '5.7', '1.32', '12.6', '68', '4', '14.3', '11', '5', '45.5', '0', '1', '2', '13', '87.1', '3 (0)', '2023', '2022', '2021', 'MIAMI OH', '57', '36', '63.2', '615', '17.1', '6', '79', '81.5', '75.6', '28.8', '-', '187', '176', '94.1', '0', '0', '97', '51.9', '89', '47.6', '1', '0.5', '272', '7.6', '3.49', '14.3', '99', '2', '5.3', '16', '3', '18.8', '1', '1', '3', '24', '127.4', '2 (0)', '2023', '2022', '2021', '2020', 'GA STATE', '103', '70', '68', '877', '12.5', '7', '73.5', '73.8', '62.5', '76.7', '-', '367', '351', '9
# ...

# %%
import numpy as np
import pandas as pd
import csv

# Path to your CSV file
file_path = '/content/Transfer data project - Staging (19).csv'

# List to hold the rows
rows_list = []

try:
    with open(file_path, 'r', newline='', encoding='utf-8') as csvfile:
        csvreader = csv.reader(csvfile)

        # Skip the header row if there is one


        # Loop through the rows and add them to the list
        for row in csvreader:
            rows_list.extend(row)
except FileNotFoundError:
    print(f"Error: The file {file_path} was not found.")
except Exception as e:
    print(f"An error occurred: {e}")
print(rows_list)













def process_rows(rows_list):
    lll = []



    # Collect names until '#' is found
    names = []
    while rows_list and '#' not in rows_list[0]:
        names.append(rows_list.pop(0))  # Remove the first element

    # Reset index for new processing
    j = 0

    while names and rows_list and len(rows_list[0]) <= 5:
        ll = [names[j]]
        j += 1
        while rows_list:
            item = rows_list.pop(0)  # Remove the first element
            ll.append(item)
            if '(' in item:
                break

        lll.append(ll)

    # Recursively call the function to process the remaining rows
    return lll





result = process_rows(rows_list)








while len(rows_list) > 0:
  result.extend(process_rows(rows_list))


print(result)
print(len(result))

print(rows_list)
# print(len(lll))
for item in result:
  #print(len(item))
  if len(item) <= 39:
    result.remove(item)

for item in result:
  #print(len(item))
  if len(item) == 42:
    item.pop(-7)

for item in result:
  if len(item) != 41:
    result.remove(item)
# for item in lll:
#   if len(item) == 40:
#     print(item[-7])
#     item.insert(-6,0)
for item in result:
  print(len(item))










csv_file = 'output.csv'

#column_titles = ['Name', 'Rating', 'Position', 'Height', 'Weight', 'Former School', 'Transfer School']
x=[]
x1 = []
x2 = []
x3 = []
x4 = []
x5 = []
x6 = []
x7 = []
x8 = []
x9 = []
x10 = []
x11 = []
x12 = []
x13 = []
x14 = []
x15 = []
x16 = []
x17 = []
x18 = []
x19 = []
x20 = []
x21 = []
x22 = []
x23 = []
x24 = []
x25 = []
x26 = []
x27 = []
x28 = []
x29 = []
x30 = []
x31 = []
x32 = []
x33 = []
x34 = []
x35 = []
x36 = []
x37 = []
x38 = []
x39 = []
x40 = []






for item in result:
    x.append(item[0])
    x1.append(item[1])
    x2.append(item[2])
    x3.append(item[3])
    x4.append(item[4])
    x5.append(item[5])
    x6.append(item[6])
    x7.append(item[7])
    x8.append(item[8])
    x9.append(item[9])
    x10.append(item[10])
    x11.append(item[11])
    x12.append(item[12])
    x13.append(item[13])
    x14.append(item[14])
    x15.append(item[15])
    x16.append(item[16])
    x17.append(item[17])
    x18.append(item[18])
    x19.append(item[19])
    x20.append(item[20])
    x21.append(item[21])
    x22.append(item[22])
    x23.append(item[23])
    x24.append(item[24])
    x25.append(item[25])
    x26.append(item[26])
    x27.append(item[27])
    x28.append(item[28])
    x29.append(item[29])
    x30.append(item[30])
    x31.append(item[31])
    x32.append(item[32])
    x33.append(item[33])
    x34.append(item[34])
    x35.append(item[35])
    x36.append(item[36])
    x37.append(item[37])
    x38.append(item[38])
    x39.append(item[39])
    x40.append(item[40])







with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)



    for data in zip(x, x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,x16,x17,x18,x19,x20,x21,x22,x23,x24,x25,x26,x27,x28,x29,x30,x31,x32,x33,x34,x35,x36,x37,x38,x39,x40):
        writer.writerow(data)
# Out:
# ['Isaiah Neyor', 'DeAndre Moore Jr.', 'Casey Cain', 'Johntay Cook II', 'Jordan Whittington', 'Adonai Mitchell', 'Xavier Worthy', 'Gunnar Helm', "Ja'Tavion Sanders", 'Quinn Ewers', 'Jaydon Blue', 'Keilan Robinson', 'CJ Baxter', 'Jonathon Brooks', 'Byron Murphy II', '# 09', 'WR', '1', '2', '1', '50', '14', '14', '0', '56.6', '57', '24.9', '61', '-', '6', '4', '66.7', '0', '0', '3', '50', '3', '50', '0', '0', '2', '2', '3.5', '10', '14', '1', '50', '1', '1', '100', '0', '0', '0', '1', '72.9', '0 (0)', '# 11', 'WR', '3', '2', '0', '0', '0', '0', '53.4', '51.9', '-', '61.9', '-', '14', '13', '92.9', '0', '0', '13', '92.9', '1', '7.1', '0', '0', '0', '0', '6.5', '0', '0', '1', '0', '0', '0', '0', '0', '0', '39.6', '0 (0)', '# 08', 'WR', '4', '2', '1', '50', '13', '13', '0', '60', '58.8', '66.7', '61', '-', '17', '17', '100', '0', '0', '2', '11.8', '15', '88.2', '0', '0', '5', '5', '0.76', '18', '13', '0', '0', '1', '0', '0', '0', '0', '0', '1', '70.8', '0 (0)', '# 02', 'WR', '11', '11', '7
# ...
